# %% [markdown]
# # Taxi data highlights -- as text processing
#
# Spring 2018 - Prof. Foster Provost
#
# Teacher Assistant: Nicholas Garcia
#
# ***
#
# This notebook helps to see some examples of the code that the students developed for the analysis of the taxi data for homework 1 ... and more! Recall that homework 1 involved a sample of NYC taxi records, used to help gain experience with data frames and ipython notebooks. In particular, students were asked to take a sample of the data set and find patterns related to dropoffs and date-time of the trips.
#
# What did they do?  What did they say?
#
# Which basic python commands did they use?
#
# ***

# %% [markdown]
# ## Clean the patterns file
#
# The patterns students found are stored in a text-file called "patterns_hw.txt".
#
# ***
# Let's run the following cell and then see:
#
# What does each line is doing?
#
# Why do we need to reset the index?
#
# Why do we need to drop duplicates?

# %%
import pandas as pd
pd.options.display.max_colwidth = 500

patterns = pd.read_table("data/patterns_hw.txt", sep='\|', header=None,index_col=1,names=["Texts"],engine='python')


###### Each of the following lines could be commented (one at a time) to see the effect

patterns.reset_index(drop=True,inplace=True)
patterns.drop_duplicates(inplace=True)
patterns.dropna(inplace=True)
patterns.replace(regex="#",value="comment: ",inplace=True)
patterns.replace(regex="code:",value="code: ",inplace=True)

patterns.head(10)
# Out:
#                                                                                                                                                                                 Texts
# 0   comment: The only pattern I can see from the random sample of 20 rides is the rides that occurred later into the evening had more passengers as compared to rides during the day.
# 2                                                                                                                                                                    code: df1.corr()
# 4                                                                                                                                           code: np.unique(trips['dropoff_borough'])
# 6                                          comment: Pattern found: 1. The dropoff borough is always brooklyn. The correlation value for dropoff borough is always NaN which indicates
# 7                                                                                  comment: that the standard deviation of dropoff borough is zero which means it has the same value.
# 8                                           comment:  2. The correlation value between dropoff zipcode and dropoff datetime is 0.985 which means dropoff zipcode and dropoff datetime
# 9                                                                                                                               comment: are almost linearly dependent on each other.
# 11                                                                                                                                          code: sample_df.dropoff_datetime.unique()
# 13                                                                                                                                comment: Drop-offs occured between 3/1/15 - 3/29/15
# 14                                                                                                                 comment: Most drop-offs occur between hours of 17:00:00 - 23:00:00

# %% [markdown]
# ## Extract information about the code used
#
# Now we can use **substrings** to find all lines related to 'comments' or 'code'.
# This is the same idea as regex or filter.

# %%
code_patterns = patterns[ patterns['Texts'].str.contains('code:') ]
text_patterns = patterns[ patterns['Texts'].str.contains('comment:') ]

text_patterns
# Out:
#                                                                                                                                                                                                                                                                                                                                                            Texts
# 0                                                                                                                                                                              comment: The only pattern I can see from the random sample of 20 rides is the rides that occurred later into the evening had more passengers as compared to rides during the day.
# 6                                                                                                                                                                                                                     comment: Pattern found: 1. The dropoff borough is always brooklyn. The correlation value for dropoff borough is always NaN which indicates
# 7                                                                                                                                                                                                                                                             comment: that the standard deviation of dropoff borough is zero which means it has the same value.
# 8                                                                                                                                                                                                                      comment:  2. The correlation value between dropoff zipcode and dropoff datetime is 0.985 which means dropoff zipcode and dropoff datetime
# 9                                                                                                                                                                                                                                                                                                          comment: are almost linearly dependent on each other.
# 13                                                                                                                                                                                                                                                                                                           comment: Drop-offs occured between 3/1/15 - 3/29/15
# 14                                                                                                                                                                                                                                                                                            comment: Most drop-offs occur between hours of 17:00:00 - 23:00:00
# 16                                                                                                                                                                                                                                                                                                      comment: The dropoff borough is either Brooklyn or None.
# 20                                                                                                                                                                                                                                                                                                                                  comment: patterns identified
# 21                                                                                                                                                                                                                                                                                                               comment: the dropoff borough is always brooklyn
# 22                                                                                                                                                                                                                                                                                                                        comment: the tip amount is always $0.3
# 24                                                                                                           comment: The sample contains only dropoffs in Brooklyn during March 2015. Running the random sample several times has returned the same results, suggesting that the data set as a whole may only report on rides that share these characteristics.
# 26                                                                                                                                 comment: When looking at data in the dropoff_datetime column, we see that the data correspond to rides in the month of March, 2015.  There doesn’t appear to be a specific date or a time that is more prevalent than others.
# 28                                                                                                  comment: The most common dropoff ZIP code is 11201, with 5 records accounting for 25% of our set.  Second most common is 11206, with 3 records (15%), and the remainder have one or two records spread over the remaining 8 ZIP codes in this random sample.
# 30                                                                                                                                                                                                                                                      comment:  The data predominantely is from March 2015 and almost all the drop-offs seem to be in Brooklyn
# 32                                                                                                                                                                                                                                                                            comment: I created a new column to indicate the time of day the travel took place,
# 33                                                                                                                                                                                                                                                                                    comment: 4am-4pm being daytime, and tried to find a pattern based on that.
# 34                                                                                                                                                                                                                                                                      comment: One pattern that I noticed could be, people travelling to zipcode 11201 tend to
# 35                                                                                                                                                                                                                                                                                                                                 comment: do so at night time.
# 45                                                                                                                                                                                                                                                             comment: This analysis makes sense. Starting at 4 during rush hour the volume of passengers picks
# 48                                                                                                                                                                                                                                                            comment: We can clearly see from the data that most pick-ups occur in Manhattan with all drop-offs
# 51                                                                                                                                                                                                                                                    comment:  The pickups, on the other hand, can be from any of the boroughs and are not limited to Brooklyn.
# 65                                                                                                                                                                                                                                                              comment: comment:  the datetimes are all in March and the dropoffs are all in Brooklyn (or None)
# 67                                                                                                                                                                                                                                                                                                     comment:  1. All dropoff_borough desinations are Brooklyn
# 68                                                                                                                                                                                                                                                                     comment:  2. All dropoff_datetime are in the month of March in the year 2015 (March 2015)
# 69                                                                                                                                                                                                                                                            comment:  3. All dropoff_latitiude seem to be 40 degrees (which is approximately the mean as well)
# 71                                                                                                                                                                                                                                   comment:  On average, total amount is trip_distance multiplied by amount per unit distance. This rate is between 3-5 units.
# 75                                                                                                                                                                                                                                                                              comment:  trips are from the month of March in 2015, all dropoff are in Brooklyn
# 79                                                                                                                                                                                                                                                               comment:  I found that the dropoff_borough has only two results which are 'Brooklyn' and 'None'
# 80                                                                                                                                                                                                                                     comment:  And the records which's dropoff_borough is 'None' seem to have issue recording the pickup and dropoff locations
# 84                                                                                                                                                                                                                                                    comment: This file appears to contain only taxi drop-offs in March of 2015, only dropping off in Brooklyn.
# 88                                                                                                                                                                                                                      comment: Extracting only the Date, we observe that the samples have the same year and month - 03/2015 even though the exact dates differ
# 90                                                                                                                                                                                                                               comment: From the sample: The longest and shortest trips have fewer passengers and the ones in the middle have more passengers.
# 98                                                                                                                                                                                                                                        comment:  the majority of dropoff times were either during the morning and the evening, with few trips during the day.
# 102                                                                                                                                                                                                                       comment: """"" In the first step, upon describing patterns we observe that the dropoff_borough has one unique entry with a count of 20
# 103                                                                                                                                                                                                                    comment: effectively suggesting that all the destinations are in one borough, which in this case is BROOKLYN, while at this point in time
# 104                                                                                                                                                                                                                        comment: the dropoff_datetime has all distinct entities, while the dropoff_zip_code suggests that there are some areas where multiple
# 105                                                                                                                                                                                                                                                                   comment: dropoffs have taken place, considering that of the 20 entries, 12 are unique"""""
# 111                                                                                                                                         comment:  Converted dates into date-time form to extract unique months, years and days. We can see that the data we got in the random set reflects dropp offs for the year 2015 and in particular the month of March
# 115                                                                                                                                                                                                                                                      comment:  The dropoff_borough of each trip was Brooklyn, hence all the dropoff_zip_codes start with 112
# 121                                                                             comment:  Observed that trips with the longest distance occurred during high peak times, either early AM hours (possible airport trips or daily commutes), or afternoon hours between 4 and 10 pm. Other times (off-peak) had shorter durations and resulting lower trip amounts
# 123                                                                                                                                                                                                               comment:  Trips from Manhattan appear to occur most frequently early and late in the day. This makes sense, since people are likely commuting.
# 127                                                                                                                                                                                                                                               comment: As might be expected, the trip times (or the difference between dropoff and pickup) tend to be longer
# 128                                                                                                                                                                                                                                                                                     comment: during rush-hour as opposed to trips occuring at off-peak hours
# 136                                                                                                                                                                                                                        comment: comment:  Several samples of 0 tips for brooklyn to brooklyn. Surprisingly, no samples of trips from manhattan to manhattan.
# 146  comment: The dropoff_borough has only one value and that is Brooklyn. Thus, this file contains records of all the trips with destination Brooklyn. We can also conclude that all the pickup_datetime and dropoff_datetime are for March 2015. Hence, this file contains all the trips that have Brooklyn as the destination for the month of March in 2015.
# 158                                                                                                                                                                                                                                                                                                        comment:  All dropoffs in sample happened in Brooklyn
# 160                                                                                                                                                                                                                                                                              comment:  In the sample, dropoffs are most common on Sunday, followed by Friday
# 164                                                                                                                                                                                                                                                               comment:  It seems they are all dropped off in Brooklyn. Maybe we can map out their pickup and
# 167                                                                                                                                                                                                                                                                                      comment:  Starting at 4 during rush hour the volume of passengers picks

# %% [markdown]
# ** Learn how to export your data ! **

# %%
import os
try: os.remove('data/code.txt')
except: None
try: os.remove('data/texts.txt')
except: None
    
code_patterns.to_csv(r'data/code.txt', header=None, index=None, sep=' ', mode='a')
text_patterns.to_csv(r'data/texts.txt', header=None, index=None, sep=' ', mode='a')

# %% [markdown]
# ### World cloud generator !
#
# A fun way to visualize which are the most common words/code used with a 'word cloud'.
#
# The github repo of _wordcloud_ has more details about this library. [Github link](https://github.com/amueller/word_cloud)
#
# ***
#
# For this task we want to remove words that are not relevant--such words are called **"STOPWORDS"**. Normally stopwords are common words (frequently used) mainly for grammatical or discourse purposes, rather than for content purposes. So for example, the words 'the', 'and', 'of', and 'on' are considered stopwords since they are very common in English (we can consider a list of stopwords for any other language as well).
#
# *Note that what words you would use as stopwords of course depends on the task!  In your business understanding/data understanding you would think through the appropriate stopword definition, rather than just using some common dictionary.  As an example, if you were doing author identification for anonymous writing, you likely **would** want to include a lot of discourse words, as people tend to have "signatures" in the words they use.  After reading the class text, you probably would be much better able to identify something that Tom and Foster wrote.  "It turns out" that each of us has a signature in our writing.  If you scrutinized the text carefully, you might even be able to figure out parts that are written by the different authors, simply based on style*
#
# Nonetheless, for this exercise, we can start our set of _stopwords_ with one built-in set provided by the _wordcloud_ library (and there are other libraries with their own lists too). Then, we'll add to the set any unnecessary words we might decide on for our specific problem (e.g. we'll drop "dropoff_datetime" because it's obvious that all of you should have used this word in your code or comments).

# %%
from wordcloud import WordCloud, STOPWORDS
# if you get an error here open a terminal window in Jupyter and enter "sudo pip install wordcloud".
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

print (STOPWORDS)
# Out:
# {'but', 'again', 'else', "we've", 'whom', "hasn't", "what's", "couldn't", 'that', 'under', 'cannot', 'it', 'once', 'other', 'while', 'so', 'further', "shouldn't", 'too', 'through', 'just', 'by', 'as', 'then', 'few', 'ever', 'were', 'only', 'they', 'about', 'out', 'them', "can't", 'down', 'him', "haven't", "i've", "i'm", "weren't", 'or', 'into', "he'd", "we'd", 'had', 'if', 'its', "she's", 'no', 'because', 'you', 'he', 'more', "mustn't", 'until', 'http', 'those', 'from', 'be', 'over', 'me', 'before', "there's", "when's", 'themselves', 'have', "don't", 'did', 'our', 'not', 'itself', "let's", 'yourselves', 'when', 'during', 'who', 'these', 'yourself', 'some', 'very', 'do', "you'd", "i'd", 'with', 'and', 'why', "they'd", 'what', 'she', 'we', 'com', "won't", "you've", 'himself', 'in', "he's", "hadn't", 'this', "isn't", 'should', "you're", 'www', 'after', 'having', 'my', 'myself', 'own', 'i', 'of', 'shall', 'each', "that's", 'at', 'on', 'here', "i'll", 'hers', "they're", 'k', 'all', 'has', 'where', "you'll", "where's", 'which', "didn't", "doesn't", 'yours', 'off', "they've", 'than', 'would', 'theirs', 'like', 'your', "we'll", 'her', "they'll", 'such', 'can', 'are', "who's", 'is', "aren't", 'above', 'the', "how's", "we're", 'ourselves', 'ours', "why's", 'their', "he'll", 'between', "here's", 'nor', 'there', "shan't", 'how', 'been', 'was', 'most', 'against', 'an', 'both', 'herself', 'ought', "wasn't", 'up', "wouldn't", 'a', 'his', "it's", 'same', 'below', 'any', 'for', 'doing', 'could', 'does', "she'd", 'being', 'am', 'to', 'get', "she'll", 'r'}

# %%
# Use stop words
stopwords = set(STOPWORDS)
stopwords.add("code")
stopwords.add("comment")
stopwords.add("trips")
stopwords.add("dropoff")
stopwords.add("dropoff_datetime'")
stopwords.add("dropoff_zip_code'")
stopwords.add("pattern")
stopwords.add("pd")
stopwords.add("sample")
stopwords.add("to_datetime")
stopwords.add("one")
stopwords.add("df2")

# %%
# Create the cloud
worldcloud_create = WordCloud(background_color="white",max_words=5000,stopwords=stopwords)
code_text = open('data/code.txt').read()
worldcloud_create.generate(code_text)

# Display results
# %matplotlib inline
plt.figure(figsize = (12,7))
plt.imshow(worldcloud_create)
plt.axis("off")
plt.show()

# %% [markdown]
# ** You can also use a mask to display results:  http://www.stencilry.org/stencils/ **

# %%
pp_mask = np.array(Image.open("data/pp.jpg"))


# Create the cloud
worldcloud_create = WordCloud(background_color="white", mask=pp_mask,
               stopwords=stopwords)
code_text = open('data/texts.txt').read()
worldcloud_create.generate(code_text)

# Display results
# %matplotlib inline
plt.figure(figsize = (12,12))
plt.imshow(worldcloud_create,aspect='auto')
plt.axis("off")
plt.show()
